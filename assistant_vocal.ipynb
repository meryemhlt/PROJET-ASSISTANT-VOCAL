# %%
pip install playsound
# Out:
# Requirement already satisfied: playsound in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (1.3.0)
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install gTTS
# Out:
# Requirement already satisfied: gTTS in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (2.5.1)
# Requirement already satisfied: click<8.2,>=7.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from gTTS) (8.1.7)
# Requirement already satisfied: requests<3,>=2.27 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from gTTS) (2.31.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests<3,>=2.27->gTTS) (2.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests<3,>=2.27->gTTS) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests<3,>=2.27->gTTS) (2024.2.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests<3,>=2.27->gTTS) (3.6)
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openai==0.28
# Out:
# Collecting openai==0.28
#   Using cached openai-0.28.0-py3-none-any.whl (76 kB)
# Requirement already satisfied: requests>=2.20 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openai==0.28) (2.31.0)
# Requirement already satisfied: aiohttp in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openai==0.28) (3.9.3)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openai==0.28) (4.66.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests>=2.20->openai==0.28) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests>=2.20->openai==0.28) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests>=2.20->openai==0.28) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests>=2.20->openai==0.28) (2024.2.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from aiohttp->openai==0.28) (6.0.5)
# Requirement already satisfied: frozenlist>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from aiohttp->openai==0.28) (1.4.1)
# Requirement already satisfied: attrs>=17.3.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from aiohttp->openai==0.28) (23.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from aiohttp->openai==0.28) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from aiohttp->openai==0.28) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from aiohttp->openai==0.28) (1.9.4)
# Installing collected packages: openai
# Successfully installed openai-0.28.0
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip show openai
# Out:
# Name: openai
# Version: 0.28.0
# Summary: Python client library for the OpenAI API
# Home-page: https://github.com/openai/openai-python
# Author: OpenAI
# Author-email: support@openai.com
# License:
# Location: /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages
# Requires: aiohttp, requests, tqdm
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyobjc
# Out:
# Requirement already satisfied: pyobjc in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (10.1)
# Requirement already satisfied: pyobjc-framework-QuickLookThumbnailing==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-AdSupport==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-ExceptionHandling==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-FinderSync==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreBluetooth==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-AdServices==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-MailKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-Social==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-MediaLibrary==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-IOBluetoothUI==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-PushKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-AutomaticAssessmentConfiguration==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-FileProvider==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-InstantMessage==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-CallKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-MediaPlayer==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-SensitiveContentAnalysis==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-DictionaryServices==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-NetFS==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-MetalKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-Symbols==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-Accounts==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-MultipeerConnectivity==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreSpotlight==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-IntentsUI==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-ExtensionKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-BusinessChat==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-OpenDirectory==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-NetworkExtension==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-ScriptingBridge==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-BackgroundAssets==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-AudioVideoBridging==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-Vision==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreServices==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-GameController==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreML==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-UserNotifications==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-LinkPresentation==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-core==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-ImageCaptureCore==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-DataDetection==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-FileProviderUI==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-GameplayKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-Contacts==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-ModelIO==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-Network==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-GameCenter==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-ScreenTime==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-PassKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-AppleScriptKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-KernelManagement==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-LocalAuthenticationEmbeddedUI==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-VideoSubscriberAccount==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-MediaAccessibility==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-AVKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-DVDPlayback==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-Virtualization==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-DiskArbitration==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-SystemConfiguration==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-Security==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-ScreenSaver==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreAudio==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-Cinematic==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-Quartz==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-AppTrackingTransparency==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-SharedWithYou==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-Photos==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-PreferencePanes==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-ApplicationServices==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-ThreadNetwork==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-SoundAnalysis==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreWLAN==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-DiscRecordingUI==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-CFNetwork==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-SafariServices==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-PhotosUI==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-ReplayKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-ColorSync==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-libxpc==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-Collaboration==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-IOBluetooth==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreMediaIO==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-NotificationCenter==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-FSEvents==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-UserNotificationsUI==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShadersGraph==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-SceneKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-EventKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-PHASE==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-MediaToolbox==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-ContactsUI==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreHaptics==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-ServiceManagement==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreText==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-Automator==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-DiscRecording==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-WebKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-libdispatch==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-SyncServices==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-SpriteKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-CloudKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-ExternalAccessory==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-OSLog==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-Intents==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-SharedWithYouCore==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-MapKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreMIDI==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-Accessibility==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-ShazamKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-ExecutionPolicy==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreLocation==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-UniformTypeIdentifiers==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-AppleScriptObjC==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-NaturalLanguage==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-LatentSemanticMapping==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-CalendarStore==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-AVFoundation==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-ScreenCaptureKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-SecurityFoundation==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-LaunchServices==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-Cocoa==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-Metal==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-InstallerPlugins==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreMedia==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreData==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-GameKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-IOSurface==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-SystemExtensions==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-MetricKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreAudioKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-AuthenticationServices==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-VideoToolbox==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-MLCompute==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-ClassKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-StoreKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-HealthKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-AddressBook==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-OSAKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-CryptoTokenKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreMotion==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-PencilKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-Speech==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-SafetyKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-DeviceCheck==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-MetalFX==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShaders==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-iTunesLibrary==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-LocalAuthentication==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-InputMethodKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-SecurityInterface==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-SearchKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# Requirement already satisfied: pyobjc-framework-AVRouting==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc) (10.1)
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install SpeechRecognition
# Out:
# Requirement already satisfied: SpeechRecognition in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (3.10.1)
# Requirement already satisfied: typing-extensions in /Users/Meryem/Library/Python/3.9/lib/python/site-packages (from SpeechRecognition) (4.10.0)
# Requirement already satisfied: requests>=2.26.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from SpeechRecognition) (2.31.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests>=2.26.0->SpeechRecognition) (2024.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests>=2.26.0->SpeechRecognition) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests>=2.26.0->SpeechRecognition) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests>=2.26.0->SpeechRecognition) (2.2.1)
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyttsx3
# Out:
# Requirement already satisfied: pyttsx3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (2.90)
# Requirement already satisfied: pyobjc>=2.4 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-SharedWithYou==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-NotificationCenter==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-PushKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-WebKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-OSAKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-ContactsUI==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-QuickLookThumbnailing==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-ExecutionPolicy==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-Vision==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-CloudKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-MetalKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-MapKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-SyncServices==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-DVDPlayback==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-EventKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-InputMethodKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-SharedWithYouCore==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-FileProviderUI==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-GameplayKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-AppleScriptObjC==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-DeviceCheck==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-DiskArbitration==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreBluetooth==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-Metal==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-Accounts==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-Contacts==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-PHASE==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-Automator==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-AVRouting==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreAudioKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-FileProvider==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-Accessibility==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-AdServices==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-AppTrackingTransparency==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-ReplayKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-Cocoa==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-StoreKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-Quartz==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-SpriteKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreMotion==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreSpotlight==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-OSLog==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-MetalFX==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-DiscRecording==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-LatentSemanticMapping==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-NaturalLanguage==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-Network==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-MediaAccessibility==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-AVFoundation==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-ScreenSaver==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-PencilKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-MediaToolbox==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-GameController==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-MLCompute==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-MediaPlayer==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-Symbols==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-SystemConfiguration==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-ShazamKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-Cinematic==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-BusinessChat==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-ClassKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-IOBluetoothUI==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-ExternalAccessory==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-PassKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreMediaIO==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-SoundAnalysis==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-ExceptionHandling==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-GameCenter==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-UserNotifications==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-NetworkExtension==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-ColorSync==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-SecurityInterface==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-AuthenticationServices==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-Virtualization==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreMedia==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-OpenDirectory==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-FinderSync==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-DataDetection==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-ServiceManagement==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-ModelIO==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-SensitiveContentAnalysis==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-SearchKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-FSEvents==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreLocation==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-LocalAuthenticationEmbeddedUI==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreML==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreWLAN==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-ApplicationServices==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-ExtensionKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-LaunchServices==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-SecurityFoundation==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-IOBluetooth==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-AVKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-Speech==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-ImageCaptureCore==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-IntentsUI==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-IOSurface==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-Collaboration==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreServices==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreAudio==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-UserNotificationsUI==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-InstantMessage==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-InstallerPlugins==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-DictionaryServices==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-libdispatch==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-ScreenTime==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-SafetyKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-CallKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-AppleScriptKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-VideoToolbox==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-AdSupport==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-core==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-iTunesLibrary==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-ScreenCaptureKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-LinkPresentation==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-ThreadNetwork==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreMIDI==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-LocalAuthentication==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-BackgroundAssets==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-HealthKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-Security==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-libxpc==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-SafariServices==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-AutomaticAssessmentConfiguration==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-CFNetwork==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-KernelManagement==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-UniformTypeIdentifiers==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreHaptics==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-NetFS==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShadersGraph==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-VideoSubscriberAccount==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-Social==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-MailKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-Intents==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-SystemExtensions==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-AudioVideoBridging==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-SceneKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-DiscRecordingUI==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-MetricKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreData==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-CryptoTokenKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-PreferencePanes==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-AddressBook==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShaders==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-CalendarStore==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-PhotosUI==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-MediaLibrary==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreText==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-Photos==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-ScriptingBridge==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-GameKit==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-MultipeerConnectivity==10.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install PyAudio
# Out:
# Requirement already satisfied: PyAudio in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (0.2.14)
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openai --upgrade
# Out:
# Requirement already satisfied: openai in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (1.13.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openai) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openai) (2.6.3)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /Users/Meryem/Library/Python/3.9/lib/python/site-packages (from openai) (4.10.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openai) (4.3.0)
# Requirement already satisfied: tqdm>4 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openai) (4.66.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openai) (1.9.0)
# Requirement already satisfied: sniffio in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openai) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/Meryem/Library/Python/3.9/lib/python/site-packages (from anyio<5,>=3.5.0->openai) (1.2.0)
# Requirement already satisfied: idna>=2.8 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from anyio<5,>=3.5.0->openai) (3.6)
# Requirement already satisfied: httpcore==1.* in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from httpx<1,>=0.23.0->openai) (1.0.4)
# Requirement already satisfied: certifi in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->openai) (2.16.3)
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openai==0.27.0
# Out:
# Collecting openai==0.27.0
#   Downloading openai-0.27.0-py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.1/70.1 KB 1.5 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: requests>=2.20 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openai==0.27.0) (2.31.0)
# Requirement already satisfied: aiohttp in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openai==0.27.0) (3.9.3)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openai==0.27.0) (4.66.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests>=2.20->openai==0.27.0) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests>=2.20->openai==0.27.0) (2024.2.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests>=2.20->openai==0.27.0) (2.2.1)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests>=2.20->openai==0.27.0) (3.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from aiohttp->openai==0.27.0) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from aiohttp->openai==0.27.0) (4.0.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from aiohttp->openai==0.27.0) (6.0.5)
# Requirement already satisfied: attrs>=17.3.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from aiohttp->openai==0.27.0) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from aiohttp->openai==0.27.0) (1.4.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from aiohttp->openai==0.27.0) (1.9.4)
# Installing collected packages: openai
#   Attempting uninstall: openai
#     Found existing installation: openai 1.13.3
#     Uninstalling openai-1.13.3:
#       Successfully uninstalled openai-1.13.3
# Successfully installed openai-0.27.0
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install wikipedia
# Out:
# Requirement already satisfied: wikipedia in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (1.4.0)
# Requirement already satisfied: beautifulsoup4 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from wikipedia) (4.12.3)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from wikipedia) (2.31.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2024.2.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.2.1)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.3.2)
# Requirement already satisfied: soupsieve>1.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from beautifulsoup4->wikipedia) (2.5)
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install googlesearch-python
# Out:
# Requirement already satisfied: googlesearch-python in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (1.2.3)
# Requirement already satisfied: beautifulsoup4>=4.9 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from googlesearch-python) (4.12.3)
# Requirement already satisfied: requests>=2.20 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from googlesearch-python) (2.31.0)
# Requirement already satisfied: soupsieve>1.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from beautifulsoup4>=4.9->googlesearch-python) (2.5)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests>=2.20->googlesearch-python) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests>=2.20->googlesearch-python) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests>=2.20->googlesearch-python) (2024.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests>=2.20->googlesearch-python) (3.3.2)
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
from config import key

# %%
import speech_recognition as sr
from gtts import gTTS
import wikipedia
import re
import playsound
from googlesearch import search
import openai

openai.api_key = key

wikipedia.set_lang('fr')

def speak(text):
    tts = gTTS(text=text, lang='fr')
    tts.save("output.mp3")
    playsound.playsound("output.mp3")

def listen():
    r = sr.Recognizer()
    with sr.Microphone() as source:
        print("Je vous écoute...")
        audio = r.listen(source)

    try:
        command = r.recognize_google(audio, language='fr-FR')
        print(f"Vous avez dit: {command}")
        return command
    except sr.UnknownValueError:
        speak("Je suis désolé, je n'ai pas compris.")
        return None
    except sr.RequestError:
        speak("Je ne peux pas accéder au service de reconnaissance vocale.")
        return None

def rechercher_sur_wikipedia(sujet):
    try:
        info = wikipedia.summary(sujet, sentences=2, auto_suggest=True, redirect=True)
        return info
    except Exception as e:
        print(f"Erreur lors de la recherche sur Wikipedia: {e}")
        return None

def rechercher_sur_chatgpt(question):
    try:
        openai.api_key = key
        
        response = openai.ChatCompletion.create(
            model="gpt-3.5-turbo-1106",
            messages=[
                {"role": "system", "content": "You are a helpful assistant."},
                {"role": "user", "content": question}
            ]
        )
        
        return response['choices'][0]['message']['content'].strip()
    except Exception as e:
        print(f"Erreur lors de la recherche sur ChatGPT: {e}")
        return None
    
def rechercher_sur_autre_source(sujet):
    try:
        site_url = "https://archive.wikiwix.com/trinet/#/fr/"
        query = f"{sujet} site:{site_url}"
        result = next(search(query, num=1, stop=1, lang='fr'), None)

        if result:
            return f"Informations trouvées sur le site Wikiwix : {result}"
        else:
            return f"Aucune information trouvée sur le site Wikiwix pour {sujet}"

    except Exception as e:
        print(f"Erreur lors de la recherche sur le site Wikiwix : {e}")
        return None
    
def rechercher_information(sujet):
    info_chatgpt = rechercher_sur_chatgpt(sujet)
    if info_chatgpt:
        return info_chatgpt
    
    info_wikipedia = rechercher_sur_wikipedia(sujet)
    if info_wikipedia:
        return info_wikipedia
    
    info_autre_source = rechercher_sur_autre_source(sujet)
    if info_autre_source:
        return info_autre_source
    
    return f"Aucune information trouvée pour {sujet}"

def handle_date_question(question):
    match = re.search(r"quelle est la date de (.+)", question, re.IGNORECASE)
    if match:
        topic = match.group(1)
        info = rechercher_information(topic)
        if not info:
            speak(f"Je suis désolé, je n'ai pas trouvé d'informations pour {topic}.")
        else:
            speak(info)
    else:
        speak("Je suis désolé, je peux répondre uniquement aux questions sur les dates d'événements historiques. Veuillez formuler votre question comme suit : 'Quelle est la date de... ?'")

def main():
    speak("Bonjour, je suis votre assistant virtuel spécialisé dans les dates d'événements historiques. Quelle date souhaitez-vous connaître ?")
    while True:
        command = listen()
        if command:
            command = command.lower()
            if 'quitte' in command or 'arrête' in command or 'merci' in command:
                speak("Je vous en prie, n'hésitez pas si vous avez une autre question!")
                break
            handle_date_question(command)

if __name__ == "__main__":
    main()
# Out:
# Je vous écoute...
# Vous avez dit: quelle est la date de la guerre d'Algérie
# Je vous écoute...
# Vous avez dit: merci
